# %% [markdown]
# <a href="https://colab.research.google.com/github/saoalonsort/Natural-Language-Processing-KI-Campus/blob/main/Vectorization_practices_TFIDF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
text = ["El procesamiento de lenguaje natural es esencial hoy en día",
        "El procesamiento de lenguaje natural juega un papel muy importante hoy en día"]

# %%
bigram_vectorizer = TfidfVectorizer(ngram_range=(2, 2))

# %%
X = bigram_vectorizer.fit_transform(text)
print(bigram_vectorizer.get_feature_names_out())
# Out:
# ['de lenguaje' 'el procesamiento' 'en día' 'es esencial' 'esencial hoy'
#  'hoy en' 'importante hoy' 'juega un' 'lenguaje natural' 'muy importante'
#  'natural es' 'natural juega' 'papel muy' 'procesamiento de' 'un papel']

# %%
print(X.toarray())
# Out:
# [[0.2895694  0.2895694  0.2895694  0.40697968 0.40697968 0.2895694
#   0.         0.         0.2895694  0.         0.40697968 0.
#   0.         0.2895694  0.        ]
#  [0.23667732 0.23667732 0.23667732 0.         0.         0.23667732
#   0.33264172 0.33264172 0.23667732 0.33264172 0.         0.33264172
#   0.33264172 0.23667732 0.33264172]]
