# %% [markdown]
# <a href="https://colab.research.google.com/github/saoalonsort/Natural-Language-Processing-KI-Campus/blob/main/Proyecto_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pets = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/My project pandas/Proyecto pandas/pet_supplies.csv')

# %%
pets.head()
# Out:
#                                                title  averageStar  quantity  \
# 0  Mesh Litter Spatula Poop Remover Pet Cleaning ...          0.0      9993
# 1  Rechargeable Mini Pet Communication Small Reco...          5.0      1986
# 2  Dog Cooling Bed Mat Summer Puppy Cushion Soft ...          4.5       529
# 3  Automatic Pet Feeder with Active RFID Technolo...          0.0        10
# 4  Replace Plush Cat Toy Accessories Worms Replac...          4.9    102222
#
#    tradeAmount  wishedCount
# 0       5 sold            0
# 1      28 sold           64
# 2      20 sold           38
# 3       0 sold            1
# 4  1,000+ sold          418

# %%
pets.shape
# Out:
# (1998, 5)

# %%
pets.iloc[9:500]
# Out:
#                                                  title  averageStar  quantity  \
# 9    3 in 1 Dog Steamer Brush Electric Spray Cat Ha...          4.7       912
# 10   Non-slip Cat Litter Mat With Gift Waterproof D...          4.8       275
# 11   Dog Collapsible Bowl Folding Silicone Pet Trav...          4.9     69902
# 12   Pet Dog Cat Paw Print Ink Kit Pad Baby Handpri...          4.7       918
# 13   Personalized Collar Pet ID Tag Custom Free Eng...          4.6      7883
# ..                                                 ...          ...       ...
# 495  Puppy Big Pet Dog Cat For Bath Brush Massage W...          4.7      1101
# 496  Pet Cat Door Holder Latch Prevents Dogs From E...          4.8       296
# 497  Dog Whistle To Stop Barking Device Dog Copper ...          4.4       147
# 498  New Pet Lovely Heart Sunglasses Hairpins Pet D...          5.0        65
# 499  1 Set Cat Plush Toy Gun Plush Launcher Silent ...          4.8        14
#
#      tradeAmount  wishedCount
# ...

# %%
pets['tradeAmount']
# Out:
# 0            5 sold
# 1           28 sold
# 2           20 sold
# 3            0 sold
# 4       1,000+ sold
#            ...
# 1993       142 sold
# 1994        24 sold
# 1995       135 sold
# 1996        34 sold
# 1997        92 sold
# Name: tradeAmount, Length: 1998, dtype: object

# %%
pets.loc[0]
# Out:
# title          Mesh Litter Spatula Poop Remover Pet Cleaning ...
# averageStar                                                  0.0
# quantity                                                    9993
# tradeAmount                                               5 sold
# wishedCount                                                    0
# Name: 0, dtype: object

# %%
pets['title']
# Out:
# 0       Mesh Litter Spatula Poop Remover Pet Cleaning ...
# 1       Rechargeable Mini Pet Communication Small Reco...
# 2       Dog Cooling Bed Mat Summer Puppy Cushion Soft ...
# 3       Automatic Pet Feeder with Active RFID Technolo...
# 4       Replace Plush Cat Toy Accessories Worms Replac...
#                               ...
# 1993    Dog Birthday Party Decoration Set Pet Triangle...
# 1994    PuppyToothbrush Cats Toothbrush- Pet Toothbrus...
# 1995    Dog Toy Dogs Accessories Pet Toys Plush Toys f...
# 1996    Pet Dog Cat Car Seat Belt For Accessories Good...
# 1997    350ml/550ml Portable Dog Water Bottle Bowl Out...
# Name: title, Length: 1998, dtype: object

# %%
pets.drop_duplicates()
# Out:
#                                                   title  averageStar  \
# 0     Mesh Litter Spatula Poop Remover Pet Cleaning ...          0.0
# 1     Rechargeable Mini Pet Communication Small Reco...          5.0
# 2     Dog Cooling Bed Mat Summer Puppy Cushion Soft ...          4.5
# 3     Automatic Pet Feeder with Active RFID Technolo...          0.0
# 4     Replace Plush Cat Toy Accessories Worms Replac...          4.9
# ...                                                 ...          ...
# 1993  Dog Birthday Party Decoration Set Pet Triangle...          4.8
# 1994  PuppyToothbrush Cats Toothbrush- Pet Toothbrus...          5.0
# 1995  Dog Toy Dogs Accessories Pet Toys Plush Toys f...          4.8
# 1996  Pet Dog Cat Car Seat Belt For Accessories Good...          5.0
# 1997  350ml/550ml Portable Dog Water Bottle Bowl Out...          4.9
#
#       quantity  tradeAmount  wishedCount
# 0         9993       5 sold            0
# 1         1986      28 sold           64
# ...

# %%
pets['quantity'].mean()
# Out:
# np.float64(15040.56906906907)

# %%
pets['averageStar'].median()
# Out:
# 4.7

# %%
pets['averageStar'] == 5.0
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 1993    False
# 1994     True
# 1995    False
# 1996     True
# 1997    False
# Name: averageStar, Length: 1998, dtype: bool

# %%
pets.loc[pets['averageStar'] == 5.0]
# Out:
#                                                   title  averageStar  \
# 1     Rechargeable Mini Pet Communication Small Reco...          5.0
# 7     Cats and Dogs Pet Plush Dinosaur Toys Interact...          5.0
# 29    Degradable Dog Poop Bag Dispenser LED light Wa...          5.0
# 30    Dog Shock Collar - Dog Training Collar for Dog...          5.0
# 32    Dog Poop Bags Dispenser LED Light Dog Waste Ba...          5.0
# ...                                                 ...          ...
# 1987  1Pcs Pet Tie Mix Colors Dog Cat Striped Bow Ti...          5.0
# 1988  Cute Cartoon Pet Beds for Small Medium Dogs Wi...          5.0
# 1990  50PCS Fashion Cute Dog Bowties For Small Dog C...          5.0
# 1994  PuppyToothbrush Cats Toothbrush- Pet Toothbrus...          5.0
# 1996  Pet Dog Cat Car Seat Belt For Accessories Good...          5.0
#
#       quantity tradeAmount  wishedCount
# 1         1986     28 sold           64
# 7           78     98 sold           85
# ...

# %%
pets.loc[(pets['averageStar'] == 5.0) & (pets['wishedCount'] == 14)]
# Out:
#                                                   title  averageStar  \
# 528   Remote Control Toy Car Indoor Accessories Pet ...          5.0
# 646   Pet Cleaning Wipes Remove Dirt From Eyes And E...          5.0
# 712   Round Head Pet Toothbrush Remove Bad Breath Ta...          5.0
# 972   40pcs Pet Dog Bowtie Lace Small Dog Cat Groomi...          5.0
# 1201  A mini cartoon cow plush toy for pet grinding ...          5.0
# 1312  Tick Remover Tool Professional Tick Removal Tw...          5.0
# 1849  Silicone Dog Treat Bag Pet Portable Dog Traini...          5.0
# 1930  Bite-resistant Pet Dog Toy Rubber Ball Beef-fl...          5.0
# 1994  PuppyToothbrush Cats Toothbrush- Pet Toothbrus...          5.0
# 1996  Pet Dog Cat Car Seat Belt For Accessories Good...          5.0
#
#       quantity tradeAmount  wishedCount
# 528       2382     31 sold           14
# 646         34     10 sold           14
# 712         61     19 sold           14
# 972         29     29 sold           14
# ...

# %%
pets.loc[pets['averageStar'].isin([5.0, 4.9])]
# Out:
#                                                   title  averageStar  \
# 1     Rechargeable Mini Pet Communication Small Reco...          5.0
# 4     Replace Plush Cat Toy Accessories Worms Replac...          4.9
# 7     Cats and Dogs Pet Plush Dinosaur Toys Interact...          5.0
# 11    Dog Collapsible Bowl Folding Silicone Pet Trav...          4.9
# 29    Degradable Dog Poop Bag Dispenser LED light Wa...          5.0
# ...                                                 ...          ...
# 1990  50PCS Fashion Cute Dog Bowties For Small Dog C...          5.0
# 1992  New Pet Lovely Heart Sunglasses Hairpins Pet D...          4.9
# 1994  PuppyToothbrush Cats Toothbrush- Pet Toothbrus...          5.0
# 1996  Pet Dog Cat Car Seat Belt For Accessories Good...          5.0
# 1997  350ml/550ml Portable Dog Water Bottle Bowl Out...          4.9
#
#       quantity  tradeAmount  wishedCount
# 1         1986      28 sold           64
# 4       102222  1,000+ sold          418
# ...
